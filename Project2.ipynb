# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns #sits on top of matplotlib

# %matplotlib inline #allows us to see the charts/graphs within Jupyter Notebook
# Out:
# UsageError: unrecognized arguments: #allows us to see the charts/graphs within Jupyter Notebook

# %%
location= "../datasets/DC_Properties.csv"
#location = r"C:\Users\TPCF235009ur\Documents\Data Analytic Bootcamp\datasets\DC_Properties.csv"
df=pd.read_csv(location, low_memory=False)
df.tail()


#df=pd.read_csv("datasets/DC_Properties.csv")
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 158952      158952       1          0  Forced Air  Y        NaN      3      1
# 158953      158953       1          0  Forced Air  Y        NaN      4      2
# 158954      158954       2          0  Forced Air  Y        NaN      4      2
# 158955      158955       1          0   Warm Cool  Y        NaN      2      0
# 158956      158956       1          0   Warm Cool  Y        NaN      2      0
#
#            AYB  YR_RMDL   ...     LONGITUDE       ASSESSMENT_NBHD  \
# 158952  1938.0   2006.0   ...     -77.01942            Old City 2
# 158953  1938.0   2006.0   ...     -77.01942            Old City 2
# 158954  1920.0   2007.0   ...     -77.01942            Old City 2
# 158955  1965.0      NaN   ...     -77.01823  Southwest Waterfront
# 158956  1965.0      NaN   ...     -77.01823  Southwest Waterfront
#
#        ASSESSMENT_SUBNBHD  CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'QUALIFIED',
#        'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE', 'CNDTN',
#        'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES', 'USECODE',
#        'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM', 'LIVING_GBA',
#        'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID', 'LATITUDE',
#        'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD', 'CENSUS_TRACT',
#        'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv("../datasets/DC_Properties.csv", encoding = "ISO-8859-1") #1st column needs encoding to read pound/hashtag(#) symbol
df.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0   ...    -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0   ...    -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0   ...    -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0   ...    -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0   ...    -77.039361       Old City 2   040 D Old City 2
#
# ...

# %%
#rename the pound/hashtag(#) column so it doesn't cause further issues
df.rename(columns={'#': 'Number'}, inplace =True)

# %%
#validate
df.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0   ...    -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0   ...    -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0   ...    -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0   ...    -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0   ...    -77.039361       Old City 2   040 D Old City 2
#
# ...

# %%
#set indices as  numbers
df.set_index('AYB', inplace=True)
df.head()
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# AYB
# 1910.0           0       4          0      Warm Cool  Y        2.0      8
# 1898.0           1       3          1      Warm Cool  Y        2.0     11
# 1910.0           2       3          1  Hot Water Rad  Y        2.0      9
# 1900.0           3       3          1  Hot Water Rad  Y        2.0      8
# 1913.0           4       2          1      Warm Cool  Y        1.0     11
#
#         BEDRM  YR_RMDL   EYB   ...     LONGITUDE ASSESSMENT_NBHD  \
# AYB                            ...
# 1910.0      4   1988.0  1972   ...    -77.040832      Old City 2
# 1898.0      5   2007.0  1972   ...    -77.040764      Old City 2
# 1910.0      5   2009.0  1984   ...    -77.040678      Old City 2
# 1900.0      5   2003.0  1984   ...    -77.040629      Old City 2
# 1913.0      3   2012.0  1985   ...    -77.039361      Old City 2
#
#         ASSESSMENT_SUBNBHD CENSUS_TRACT  CENSUS_BLOCK    WARD  SQUARE  \
# AYB
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE', 'QUALIFIED',
#        'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE', 'CNDTN',
#        'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES', 'USECODE',
#        'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM', 'LIVING_GBA',
#        'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID', 'LATITUDE',
#        'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD', 'CENSUS_TRACT',
#        'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
#make a scatterplot
sns.lmplot(x='BEDRM', y= 'PRICE', data=df)

# %%
#add more details to scatterplot
sns.lmplot(x='BEDRM', y= 'PRICE', data=df, 
           fit_reg=False, #remove regression line
           hue='PRICE')   #color by evolution stage
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
# ...

# %%
#make a scatterplot
sns.lmplot(x='CITY', y= 'PRICE', data=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-0c28d5082f10> in <module>
#       1 #make a scatterplot
# ----> 2 sns.lmplot(x='CITY', y= 'PRICE', data=df)
#
# ~\Anaconda3\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     576     if sharex:
#     577         for ax in facets.axes.flat:
# --> 578             ax.scatter(data[x], np.ones(len(data)) * data[y].mean()).remove()
#     579
#     580     # Draw the regression plot on each facet
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...
